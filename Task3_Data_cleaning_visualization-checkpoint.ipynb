# %%
import pandas as pd

df = pd.read_csv("D:/DATA SCIENCE/students.csv")

print(df.head())
# Out:
#       Name  Age  Marks
# 0  Sumanth   20     85
# 1    Rahul   21     90
# 2    Priya   19     88
# 3     Ravi   22     75
# 4      Anu   20     92

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     5 non-null      int64
#  2   Marks   5 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 252.0 bytes
# None
#              Age      Marks
# count   5.000000   5.000000
# mean   20.400000  86.000000
# std     1.140175   6.670832
# min    19.000000  75.000000
# 25%    20.000000  85.000000
# 50%    20.000000  88.000000
# 75%    21.000000  90.000000
# max    22.000000  92.000000

# %%
print(df.isnull().sum())
# Out:
# Name     0
# Age      0
# Marks    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df['Marks'].hist(bins=5)

plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns

sns.scatterplot(x='Age', y='Marks', data=df)

plt.title("Age vs Marks")
plt.show()

# %%
print(df[['Age','Marks']].corr())
# Out:
#             Age     Marks
# Age    1.000000 -0.657383
# Marks -0.657383  1.000000

# %%
print("EDA PROJECT SUMMARY")
print("-------------------")

print("Total Students:", len(df))
print("Average Age:", df['Age'].mean())
print("Average Marks:", df['Marks'].mean())
print("Highest Marks:", df['Marks'].max())
print("Lowest Marks:", df['Marks'].min())
# Out:
# EDA PROJECT SUMMARY
# -------------------
# Total Students: 5
# Average Age: 20.4
# Average Marks: 86.0
# Highest Marks: 92
# Lowest Marks: 75
